# %%
a=5
b=2
a=b
print(a)
# Out:
# 2

# %%
a=5
b=2
a=a+b
print(a)
# Out:
# 7

# %%
a=5
b=2
a=a-b
print(a)
# Out:
# 3

# %%
a=5
b=2
a=a*b
print(a)
# Out:
# 10

# %%
a=5
b=2
a=a/b
print(a)
# Out:
# 2.5

# %%
a=5
b=2
a=a//b
print(a)
# Out:
# 2

# %%
a=5
b=2
a=a%b
print(a)
# Out:
# 1

# %%
a=5
b=2
a=a**b
print(a)
# Out:
# 25
